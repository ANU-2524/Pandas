# %%
import pandas as pd 

fileLoc = "./vgsales.csv"

# Read whole data , otherwise can use DataFrame for raw data  !
data = pd.read_csv(fileLoc)

# only get Rank and Name column !
rank_name = pd.read_csv(fileLoc , usecols = ["Rank" , "Name"] , index_col = "Rank")
print(rank_name)
                        
print(data.columns)
# Out:
#                                                    Name
# Rank
# 1                                            Wii Sports
# 2                                     Super Mario Bros.
# 3                                        Mario Kart Wii
# 4                                     Wii Sports Resort
# 5                              Pokemon Red/Pokemon Blue
# ...                                                 ...
# 16596                Woody Woodpecker in Crazy Castle 5
# 16597                     Men in Black II: Alien Escape
# 16598  SCORE International Baja 1000: The Official Game
# 16599                                        Know How 2
# 16600                                  Spirits & Spells
#
# [16598 rows x 1 columns]
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %%
print("All Columns in dataset" , data.columns )
print()

# set index to column Rank
data.set_index("Rank")

# Rows from start !
print(data.head())

# Rows from end !
print(data.tail())
# Out:
# Columns in dataset Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# ...

# %%
newDemoFile = data.head(10)
print(type(newDemoFile))
newFileContent = newDemoFile.to_csv(index = False)
print(type(newFileContent))
print("newDemoFile data \n" , newDemoFile)
print("newFileContent data \n" , newFileContent)
with open("first_10_row.csv" , "w") as file :
    file.write(newFileContent)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'str'>
# newDemoFile data
#     Rank                       Name Platform    Year         Genre Publisher  \
# 0     1                 Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2          Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3             Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4          Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5   Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
# 5     6                     Tetris       GB  1989.0        Puzzle  Nintendo
# 6     7      New Super Mario Bros.       DS  2006.0      Platform  Nintendo
# 7     8                   Wii Play      Wii  2006.0          Misc  Nintendo
# 8     9  New Super Mario Bros. Wii      Wii  2009.0      Platform  Nintendo
# 9    10                  Duck Hunt      NES  1984.0       Shooter  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# ...

# %%
from sklearn.linear_model import LogisticRegression
modell  = LogisticRegression()
print(modell)
# Out:
# LogisticRegression()
